# %%
import pandas as pd 
import numpy as np
from numpy.random import randn
# %matplotlib inline
df1 = pd.read_csv("../whr/2016.csv")
df2= pd.read_csv("../whr/2015.csv")
print(df1)
# Out:
#                   Country                           Region  Happiness Rank  \
# 0                 Denmark                   Western Europe               1
# 1             Switzerland                   Western Europe               2
# 2                 Iceland                   Western Europe               3
# 3                  Norway                   Western Europe               4
# 4                 Finland                   Western Europe               5
# 5                  Canada                    North America               6
# 6             Netherlands                   Western Europe               7
# 7             New Zealand        Australia and New Zealand               8
# 8               Australia        Australia and New Zealand               9
# 9                  Sweden                   Western Europe              10
# 10                 Israel  Middle East and Northern Africa              11
# ...

# %%
df2.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
import pandas as pd 
import numpy as np
from numpy.random import randn
# %matplotlib inline
df1 = pd.read_csv("../whr/2016.csv")
df2= pd.read_csv("../whr/2015.csv")
df2.plot.area(alpha=0.5)

# %%
df2.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df2.plot.bar()

# %%
df2.plot.bar(stacked=True)

# %%
df2.plot.box()

# %%
df2.plot.scatter(x='Family',y='Happiness Score',s=df1['Happiness Score']*200)

# %%
df1
# Out:
#                   Country                           Region  Happiness Rank  \
# 0                 Denmark                   Western Europe               1
# 1             Switzerland                   Western Europe               2
# 2                 Iceland                   Western Europe               3
# 3                  Norway                   Western Europe               4
# 4                 Finland                   Western Europe               5
# 5                  Canada                    North America               6
# 6             Netherlands                   Western Europe               7
# 7             New Zealand        Australia and New Zealand               8
# 8               Australia        Australia and New Zealand               9
# 9                  Sweden                   Western Europe              10
# 10                 Israel  Middle East and Northern Africa              11
# ...

# %%
df1.describe()
# Out:
#        Happiness Rank  Happiness Score  Lower Confidence Interval  \
# count      157.000000       157.000000                 157.000000
# mean        78.980892         5.382185                   5.282395
# std         45.466030         1.141674                   1.148043
# min          1.000000         2.905000                   2.732000
# 25%         40.000000         4.404000                   4.327000
# 50%         79.000000         5.314000                   5.237000
# 75%        118.000000         6.269000                   6.154000
# max        157.000000         7.526000                   7.460000
#
#        Upper Confidence Interval  Economy (GDP per Capita)      Family  \
# count                 157.000000                157.000000  157.000000
# mean                    5.481975                  0.953880    0.793621
# std                     1.136493                  0.412595    0.266706
# min                     3.078000                  0.000000    0.000000
# ...

# %%
df1.hist(figsize = (20,15))
plt.show()

# %%
df1.plot.scatter(x='Freedom',y='Happiness Score',c='blue',s=100,figsize=(12,3))

# %%
df2.plot.area(alpha=0.4)

# %%
df1['Lower Confidence Interval'].hist()

# %%
import matplotlib.pyplot as plt
plt.style.use('dark_background')
df1['Happiness Score'].hist()

# %%
df1.plot()

# %%
import matplotlib.pyplot as plt
df2= pd.read_csv("../whr/2015.csv")

plt.scatter(df2['Freedom'],df2['Happiness Score'])
plt.show()

# %%
import matplotlib.pyplot as plt
df2= pd.read_csv("../whr/2015.csv")

fig, axes = plt.subplots(1,1)

axes.scatter(x=df2['Freedom'], y=df2['Happiness Score'],c='r')
axes.set_xlabel('Happiness Score')
axes.set_ylabel('Family')
axes.set_title('2015')

# %%
import matplotlib.pyplot as plt
df1= pd.read_csv("../whr/2016.csv")

fig, axes = plt.subplots(1,1)

axes.scatter(x=df1['Freedom'], y=df1['Happiness Score'],c='r')
axes.set_xlabel('Happiness Score')
axes.set_ylabel('Family')
axes.set_title('2016')

# %%
fig, axes = plt.subplots(1,1)

axes.scatter(x=df1['Economy (GDP per Capita)'], y=df1['Happiness Score'],c='r')
axes.set_xlabel('Happiness Score')
axes.set_ylabel('Economy (GDP per Capita)')
axes.set_title('2016')

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# Fixing random state for reproducibility
np.random.seed(19680801)


matplotlib.rcParams['axes.unicode_minus'] = False
fig, ax = plt.subplots()
ax.plot(10*np.random.randn(100), 10*np.random.randn(100), 'o')
ax.set_title('Using hyphen instead of Unicode minus')
plt.show()

# %%
import numpy as np
from numpy.random import rand
np.random.seed(50)
df= pd.DataFrame(rand(3,3),['Economy (GDP per Capita)','Health (Life Expectancy)','Family'],['Freedom','Generosity','Happiness Rank'])
print(df)
# Out:
#                            Freedom  Generosity  Happiness Rank
# Economy (GDP per Capita)  0.494602    0.228083        0.255474
# Health (Life Expectancy)  0.396330    0.377315        0.996574
# Family                    0.408197    0.771894        0.760537

# %% [markdown]
# Visualization with seaborn

# %%
import seaborn as sns
# %matplotlib inline
sns.distplot(df1['Happiness Score'])

# %%
sns.distplot(df1['Happiness Score'],kde=False,bins = 50)

# %%
sns.jointplot(x='Health (Life Expectancy)',y='Happiness Rank',data=df1,kind='scatter')

# %%
sns.pairplot(df1)

# %%
sns.pairplot(df1)
sns.fig.set_size_inches(15,15)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-3c5f3e09e039> in <module>()
#       1 sns.pairplot(df1)
# ----> 2 sns.fig.set_size_inches(15,15)
#
# AttributeError: 'module' object has no attribute 'fig'

# %%
sns.pairplot(df1,hue='Happiness Rank',palette='coolwarm')

# %% [markdown]
# Categorie plot : box plot

# %%
sns.boxplot(x="Happiness Rank", y="Economy (GDP per Capita)", hue="Country",data=df1, palette="coolwarm")
